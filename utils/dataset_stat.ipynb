# %%
import glob
import os

# %%
dir_path = '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20'
list_dirs = glob.glob(os.path.join(dir_path, 'train', '*'))

# %%
num_classes = len(list_dirs)

# %%
for i in range(num_classes):
    num_imgs = len(glob.glob(os.path.join(list_dirs[i], '*anchor.png')))
    if num_imgs != 1300:
        print(list_dirs[i])

# %%
glob.glob(os.path.join(list_dirs[i], '*.png'))
# Out:
# ['/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample00332_1.0_4.png',
#  '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample01253_1.0_3.png',
#  '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample00620_1.0_14.png',
#  '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample00188_anchor.png',
#  '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample00540_1.0_2.png',
#  '/data/vision/phillipi/ganclr/datasets/bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20/train/n04592741/seed0908_sample00699_1.0_13.png',
# ...

# %%
# !ls '/data/vision/phillipi/ganclr/datasets/'
# Out:
# bigbi_resnet_128_gauss1_std0.2_imagenet100_N20
# bigbi_resnet_128_gauss1_std0.3_imagenet100_N20
# bigbi-resnet_128_gauss_angular_std0.2_imagenet100_N20
# bigbi-resnet_128_gauss_angular_std0.3_imagenet100_N20
# big_deep256_tr1.0_gauss1_std1.0_imagenet100_N20
# big_deep256_tr1.0_gauss_angular_std1.0_imagenet100_N20
# big_deep256_tr1.0_steer_composite1_imagenet100_N5
# biggan256tr1-png_rnd_indep_1_samples
# biggan256tr1-png_rnd_indep_20_samples
